# %%
import pycaret

# %%
from pycaret.datasets import get_data

# %%
df = get_data("result/greedy")
# Out:
#    r1  r2  r3  r4  r5  r6  r7  r8  r9  r10  ...  r16  r17  r18  r19  r20  r21  \
# 0   4   2   4   1   2   2   3   2   3    3  ...    4    2    4    5    2    2
# 1   2   4   1   2   2   3   2   3   3    5  ...    2    4    5    2    2    3
# 2   4   1   2   2   3   2   3   3   5    4  ...    4    5    2    2    3    3
# 3   1   2   2   3   2   3   3   5   4    3  ...    5    2    2    3    3    3
# 4   2   2   3   2   3   3   5   4   3    5  ...    2    2    3    3    3    5
#
#    r22  r23  r24  Classes
# 0    3    3    3        5
# 1    3    3    5        2
# 2    3    5    2        6
# 3    5    2    6        4
# 4    2    6    4        4
#
# [5 rows x 25 columns]

# %%
df_train = df.sample(frac=0.9, random_state=984)
df_test = df.drop(df_train.index)
df.shape
df_train.head()
# Out:
#       r1  r2  r3  r4  r5  r6  r7  r8  r9  r10  ...  r16  r17  r18  r19  r20  \
# 2291   1   1   5   3   2   1   6   2   2    4  ...    1    4    4    3    2
# 4662   1   3   2   2   4   7   3   4   6    1  ...    4    2    4    4    5
# 3306   2   1   4   2   3   5   2   4   1    2  ...    1    7    3    5    2
# 2403   3   4   3   3   2   4   6   4   1    2  ...    8    5    4    3    3
# 1207   1   1   3   1   5   3   5   2   3    4  ...    4    5    1    5    1
#
#       r21  r22  r23  r24  Classes
# 2291    5    2    5    5        1
# 4662    2    4    1    6        2
# 3306    1    1    5    1        4
# 2403    1    1    1    4        2
# 1207    1    1    4    2        1
#
# [5 rows x 25 columns]

# %%
df_train.reset_index(drop=True, inplace=True)
df_test.reset_index(drop=True, inplace=True)

# %%
from pycaret.classification import *
s = setup(df_train, target = 'Classes')
# Out:
# <style type="text/css">
# #T_a1fae_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a1fae">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1fae_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a1fae_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1fae_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a1fae_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a1fae_row0_col1" class="data row0 col1" >3661</td>
#     </tr>
#     <tr>
#       <th id="T_a1fae_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a1fae_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a1fae_row1_col1" class="data row1 col1" >Classes</td>
#     </tr>
#     <tr>
#       <th id="T_a1fae_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
all_models = ['lr','knn','nb','dt','svm','rbfsvm','gpc','ridge','rf','ada','gbc','lda','et','dummy']
prefer_models = ['dt','rbfsvm','gbc','rf','et','knn']
# best = compare_models(include=prefer_models)
# best = compare_models(include=all_models)

# %%
for idx, item in enumerate(prefer_models):
    model = create_model(item)
    evaluate_model(model)
    save_model(model, f"model/model_{item}")
# Out:
# <style type="text/css">
# #T_b3aa1_row10_col0, #T_b3aa1_row10_col1, #T_b3aa1_row10_col2, #T_b3aa1_row10_col3, #T_b3aa1_row10_col4, #T_b3aa1_row10_col5, #T_b3aa1_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_b3aa1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3aa1_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_b3aa1_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_b3aa1_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_b3aa1_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_b3aa1_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_b3aa1_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_b3aa1_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...
